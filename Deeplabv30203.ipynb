# %% [markdown]
# <a href="https://colab.research.google.com/github/MoqiSheng/MoqiSheng.github.io/blob/main/Deeplabv30203.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/VainF/DeepLabV3Plus-Pytorch.git
# Out:
# Cloning into 'DeepLabV3Plus-Pytorch'...
# remote: Enumerating objects: 705, done.
# remote: Counting objects: 100% (37/37), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 705 (delta 25), reused 14 (delta 14), pack-reused 668 (from 2)
# Receiving objects: 100% (705/705), 8.26 MiB | 34.11 MiB/s, done.
# Resolving deltas: 100% (380/380), done.

# %%
# %cd /content/DeepLabV3Plus-Pytorch
# Out:
# /content/DeepLabV3Plus-Pytorch

# %%
# !ls /content/DeepLabV3Plus-Pytorch
# Out:
# datasets  main.py  network     README.md	 samples
# LICENSE   metrics  predict.py  requirements.txt  utils

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 91.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 36.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 96.3 MB/s eta 0:00:00
# ...

# %%
# !mkdir checkpoints

# %%
# %cd /content
# Out:
# /content

# %%
# !unzip /content/drive/MyDrive/UrbanASIFpro/Anchor.zip -d /content/DeepLabV3Plus-Pytorch/datasets/anchor
# Out:
# Archive:  /content/drive/MyDrive/UrbanASIFpro/Anchor.zip
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/anchor/1007.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/anchor/1037.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/anchor/1039.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/anchor/1052.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/anchor/1094.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/anchor/1095.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/anchor/1097.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/anchor/1104.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/anchor/111.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/anchor/1112.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/anchor/1117.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/anchor/1140.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/anchor/1142.png
# ...

# %%
# %cd /content/DeepLabV3Plus-Pytorch
# Out:
# /content/DeepLabV3Plus-Pytorch

# %%
# !python predict.py --input datasets/anchor --dataset cityscapes --model deeplabv3plus_mobilenet --ckpt checkpoints/best_deeplabv3plus_mobilenet_cityscapes_os16.pth --save_val_results_to anchor_results
# Out:
# Device: cuda
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100% 13.6M/13.6M [00:00<00:00, 116MB/s]
# ...

# %%
# !cp -r /content/DeepLabV3Plus-Pytorch/anchor_results /content/drive/MyDrive/UrbanASIFpro/anchor_results

# %%
# !unzip /content/drive/MyDrive/UrbanASIFpro/Predict_image.zip -d /content/DeepLabV3Plus-Pytorch/datasets/predict
# Out:
# Archive:  /content/drive/MyDrive/UrbanASIFpro/Predict_image.zip
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/predict/0.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/predict/1.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/predict/10.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/predict/100.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/predict/1000.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/predict/1001.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/predict/1002.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/predict/1003.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/predict/1004.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/predict/1005.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/predict/1006.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/predict/1008.png
#   inflating: /content/DeepLabV3Plus-Pytorch/datasets/predict/1009.png
# ...

# %%
# %cd /content/DeepLabV3Plus-Pytorch
# Out:
# /content/DeepLabV3Plus-Pytorch

# %%
# !python predict.py --input datasets/predict --dataset cityscapes --model deeplabv3plus_mobilenet --ckpt checkpoints/best_deeplabv3plus_mobilenet_cityscapes_os16.pth --save_val_results_to predict_results
# Out:
# Device: cuda
# /content/DeepLabV3Plus-Pytorch/predict.py:87: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ...

# %%
# !cp -r /content/DeepLabV3Plus-Pytorch/predict_results /content/drive/MyDrive/UrbanASIFpro/predict_results
