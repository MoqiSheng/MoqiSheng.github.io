# %% [markdown]
# <a href="https://colab.research.google.com/github/MoqiSheng/MoqiSheng.github.io/blob/main/add_function_vit_embedding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/UrbanASIF/unique/anchor_Shenzhen.zip -d /content/anchor
# Out:
# Archive:  /content/drive/MyDrive/UrbanASIF/unique/anchor_Shenzhen.zip
#   inflating: /content/anchor/0.png
#   inflating: /content/anchor/1.png
#   inflating: /content/anchor/100.png
#   inflating: /content/anchor/1021.png
#   inflating: /content/anchor/106.png
#   inflating: /content/anchor/1062.png
#   inflating: /content/anchor/107.png
#   inflating: /content/anchor/1073.png
#   inflating: /content/anchor/108.png
#   inflating: /content/anchor/1087.png
#   inflating: /content/anchor/1110.png
#   inflating: /content/anchor/1111.png
#   inflating: /content/anchor/1166.png
#   inflating: /content/anchor/1175.png
#   inflating: /content/anchor/118.png
#   inflating: /content/anchor/1180.png
#   inflating: /content/anchor/119.png
#   inflating: /content/anchor/121.png
#   inflating: /content/anchor/1219.png
#   inflating: /content/anchor/1232.png
#   inflating: /content/anchor/1233.png
#   inflating: /content/anchor/1246.png
#   inflating: /content/anchor/125.png
#   inflating: /content/anchor/1265.png
#   inflating: /content/anchor/1286.png
#   inflating: /content/anchor/1291.png
#   inflating: /content/anchor/13.png
#   inflating: /content/anchor/130.png
#   inflating: /content/anchor/1303.png
#   inflating: /content/anchor/1308.png
#   inflating: /content/anchor/132.png
#   inflating: /content/anchor/1320.png
#   inflating: /content/anchor/133.png
#   inflating: /content/anchor/135.png
#   inflating: /content/anchor/1356.png
#   inflating: /content/anchor/14.png
#   inflating: /content/anchor/1428.png
#   inflating: /content/anchor/144.png
#   inflating: /content/anchor/1461.png
#   inflating: /content/anchor/15.png
#   inflating: /content/anchor/157.png
#   inflating: /content/anchor/159.png
#   inflating: /content/anchor/167.png
#   inflating: /content/anchor/17.png
#   inflating: /content/anchor/174.png
#   inflating: /content/anchor/179.png
#   inflating: /content/anchor/182.png
#   inflating: /content/anchor/185.png
#   inflating: /content/anchor/187.png
#   inflating: /content/anchor/195.png
#   inflating: /content/anchor/196.png
#   inflating: /content/anchor/198.png
#   inflating: /content/anchor/2.png
#   inflating: /content/anchor/200.png
#   inflating: /content/anchor/205.png
#   inflating: /content/anchor/208.png
#   inflating: /content/anchor/21.png
#   inflating: /content/anchor/210.png
#   inflating: /content/anchor/223.png
#   inflating: /content/anchor/228.png
#   inflating: /content/anchor/23.png
#   inflating: /content/anchor/236.png
#   inflating: /content/anchor/237.png
#   inflating: /content/anchor/25.png
#   inflating: /content/anchor/256.png
#   inflating: /content/anchor/26.png
#   inflating: /content/anchor/263.png
#   inflating: /content/anchor/285.png
#   inflating: /content/anchor/293.png
#   inflating: /content/anchor/295.png
#   inflating: /content/anchor/3.png
#   inflating: /content/anchor/301.png
#   inflating: /content/anchor/304.png
#   inflating: /content/anchor/31.png
#   inflating: /content/anchor/316.png
#   inflating: /content/anchor/318.png
#   inflating: /content/anchor/33.png
#   inflating: /content/anchor/334.png
#   inflating: /content/anchor/339.png
#   inflating: /content/anchor/365.png
#   inflating: /content/anchor/377.png
#   inflating: /content/anchor/378.png
#   inflating: /content/anchor/38.png
#   inflating: /content/anchor/392.png
#   inflating: /content/anchor/4.png
#   inflating: /content/anchor/41.png
#   inflating: /content/anchor/411.png
#   inflating: /content/anchor/422.png
#   inflating: /content/anchor/43.png
#   inflating: /content/anchor/454.png
#   inflating: /content/anchor/466.png
#   inflating: /content/anchor/468.png
#   inflating: /content/anchor/474.png
#   inflating: /content/anchor/48.png
#   inflating: /content/anchor/483.png
#   inflating: /content/anchor/506.png
#   inflating: /content/anchor/517.png
#   inflating: /content/anchor/543.png
#   inflating: /content/anchor/55.png
#   inflating: /content/anchor/556.png
#   inflating: /content/anchor/57.png
#   inflating: /content/anchor/571.png
#   inflating: /content/anchor/589.png
#   inflating: /content/anchor/590.png
#   inflating: /content/anchor/593.png
#   inflating: /content/anchor/6.png
#   inflating: /content/anchor/616.png
#   inflating: /content/anchor/621.png
#   inflating: /content/anchor/637.png
#   inflating: /content/anchor/65.png
#   inflating: /content/anchor/652.png
#   inflating: /content/anchor/7.png
#   inflating: /content/anchor/70.png
#   inflating: /content/anchor/702.png
#   inflating: /content/anchor/709.png
#   inflating: /content/anchor/71.png
#   inflating: /content/anchor/717.png
#   inflating: /content/anchor/719.png
#   inflating: /content/anchor/72.png
#   inflating: /content/anchor/722.png
#   inflating: /content/anchor/73.png
#   inflating: /content/anchor/751.png
#   inflating: /content/anchor/752.png
#   inflating: /content/anchor/769.png
#   inflating: /content/anchor/781.png
#   inflating: /content/anchor/8.png
#   inflating: /content/anchor/802.png
#   inflating: /content/anchor/825.png
#   inflating: /content/anchor/858.png
#   inflating: /content/anchor/86.png
#   inflating: /content/anchor/865.png
#   inflating: /content/anchor/87.png
#   inflating: /content/anchor/873.png
#   inflating: /content/anchor/88.png
#   inflating: /content/anchor/890.png
#   inflating: /content/anchor/9.png
#   inflating: /content/anchor/915.png
#   inflating: /content/anchor/946.png
#   inflating: /content/anchor/95.png
#   inflating: /content/anchor/96.png
#   inflating: /content/anchor/98.png
#   inflating: /content/anchor/983.png
#   inflating: /content/anchor/99.png
#   inflating: /content/anchor/predict_label_primary_correct_unique.csv

# %%
import os
import torch
import pandas as pd
from transformers import ViTFeatureExtractor, ViTModel
from PIL import Image
from tqdm import tqdm
import re  # 导入正则表达式模块

# 加载预训练的 google/vit-base-patch16-224-in21k 模型
device = "cuda" if torch.cuda.is_available() else "cpu"
model = ViTModel.from_pretrained("google/vit-base-patch16-224-in21k").to(device)
feature_extractor = ViTFeatureExtractor.from_pretrained("google/vit-base-patch16-224-in21k")

# 加载 anchor_Shenzhen.csv 并将其转换为 DataFrame
csv_file = './anchor_Shenzhen.csv'
df = pd.read_csv(csv_file)
print(f"Loaded {len(df)} rows from {csv_file}")

# 定义特征提取函数 extract_features
def extract_features(image_folder, output_file):
    image_features_list = []

    # 读取 image_folder 中所有扩展名为 .jpg 或 .png 的文件，并将文件名按自然数顺序排序（例如，1.jpg、2.jpg、3.jpg 顺序排列）
    image_paths = sorted(
        [os.path.join(image_folder, img) for img in os.listdir(image_folder) if img.lower().endswith(('.jpg', '.png'))],
        key=lambda x: int(os.path.splitext(os.path.basename(x))[0])
    )
    print(f"Found {len(image_paths)} images in {image_folder}")

    for image_path in tqdm(image_paths, desc=f"Processing {image_folder}"):
        try:
            # 获取图片ID
            image_id = os.path.splitext(os.path.basename(image_path))[0]

            # 从 CSV 文件中获取对应的 primary_function 列的第一个单词
            primary_function = df.loc[df['ID'] == int(image_id), 'primary_function'].values
            if primary_function.size == 0:
                print(f"Warning: No primary_function found for image ID {image_id}, skipping.")
                continue  # 如果没有找到对应的行，跳过该图片

            # 使用正则表达式去除标点符号，提取第一个单词
            # 正则表达式 '[^\w\s]' 用于去除所有非字母和空格字符
            first_word = re.sub(r'[^\w\s]', '', primary_function[0]).split()[0]  # 去掉标点符号并取第一个单词
            print(f"Image {image_id}: Primary function is {primary_function[0]}, using {first_word} as the embedding keyword.")

            # 加载并预处理图像
            image = Image.open(image_path)
            inputs = feature_extractor(images=image, return_tensors="pt").to(device)  # 使用 ViTFeatureExtractor 进行预处理

            # 获取图像特征
            with torch.no_grad():  # 禁用了梯度计算（不需要反向传播）
                outputs = model(**inputs)  # 获取模型输出
                image_features = outputs.last_hidden_state[:, 0]  # 取 [CLS] token 的特征
                image_features /= image_features.norm(dim=-1, keepdim=True)  # 归一化处理
                image_features *= 0.8  # 对图像特征向量进行 0.8 的缩放
                print(f"Image {image_id}: Extracted features and scaled by 0.8")

                # 加载与第一个单词对应的嵌入文件（.pt）
                embedding_file = f'./{first_word}.pt'
                if os.path.exists(embedding_file):
                    word_embedding = torch.load(embedding_file).to(device)
                    image_features += 0.2 * word_embedding  # 加权叠加
                    print(f"Image {image_id}: Added embedding from {first_word}.pt with weight 0.2")
                else:
                    print(f"Warning: Embedding file {embedding_file} not found, skipping embedding addition.")

                image_features_list.append(image_features.cpu())  # 将特征向量移动到 CPU ，然后将其追加到列表中

        except Exception as e:
            print(f"Error processing {image_path}: {e}")

    # 将所有图像特征保存为矩阵
    if image_features_list:
        image_features = torch.cat(image_features_list, dim=0)  # 将存储在 image_features_list 中的所有图像特征向量拼接成一个大的张量
        torch.save(image_features, output_file)
        print(f"Features saved to {output_file}")
    else:
        print(f"No valid images found in {image_folder}")

# 调用特征提取函数，提取并保存每个城市的特征
extract_features('./anchor', './imgs_anchor')
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/vit/feature_extraction_vit.py:28: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(
# Loaded 143 rows from ./anchor_Shenzhen.csv
# Found 143 images in ./anchor
# Processing ./anchor:   0%|          | 0/143 [00:00<?, ?it/s]<ipython-input-5-3c601d4029ba>:61: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   word_embedding = torch.load(embedding_file).to(device)
# Processing ./anchor:   4%|▍         | 6/143 [00:00<00:02, 54.84it/s]
# Image 0: Primary function is civic, governmental and cultural, using civic as the embedding keyword.
# Image 0: Extracted features and scaled by 0.8
# Image 0: Added embedding from civic.pt with weight 0.2
# Image 1: Primary function is transportation, using transportation as the embedding keyword.
# Image 1: Extracted features and scaled by 0.8
# Image 1: Added embedding from transportation.pt with weight 0.2
# Image 2: Primary function is commercial, using commercial as the embedding keyword.
# Image 2: Extracted features and scaled by 0.8
# Image 2: Added embedding from commercial.pt with weight 0.2
# Image 3: Primary function is commercial, using commercial as the embedding keyword.
# Image 3: Extracted features and scaled by 0.8
# Image 3: Added embedding from commercial.pt with weight 0.2
# Image 4: Primary function is residential, using residential as the embedding keyword.
# Image 4: Extracted features and scaled by 0.8
# Image 4: Added embedding from residential.pt with weight 0.2
# Image 6: Primary function is residential, using residential as the embedding keyword.
# Image 6: Extracted features and scaled by 0.8
# Image 6: Added embedding from residential.pt with weight 0.2
# Image 7: Primary function is commercial, using commercial as the embedding keyword.
# Image 7: Extracted features and scaled by 0.8
# Image 7: Added embedding from commercial.pt with weight 0.2
# Image 8: Primary function is education, using education as the embedding keyword.
# Image 8: Extracted features and scaled by 0.8
# Image 8: Added embedding from education.pt with weight 0.2
# Image 9: Primary function is residential, using residential as the embedding keyword.
# Image 9: Extracted features and scaled by 0.8
# Image 9: Added embedding from residential.pt with weight 0.2
# Image 13: Primary function is commercial, using commercial as the embedding keyword.
# Image 13: Extracted features and scaled by 0.8
# Image 13: Added embedding from commercial.pt with weight 0.2
# Image 14: Primary function is industrial, using industrial as the embedding keyword.
# Image 14: Extracted features and scaled by 0.8
# Image 14: Added embedding from industrial.pt with weight 0.2
# Image 15: Primary function is civic, governmental and cultural, using civic as the embedding keyword.
# Processing ./anchor:  13%|█▎        | 18/143 [00:00<00:02, 55.87it/s]
# Image 15: Extracted features and scaled by 0.8
# Image 15: Added embedding from civic.pt with weight 0.2
# Image 17: Primary function is commercial, using commercial as the embedding keyword.
# Image 17: Extracted features and scaled by 0.8
# Image 17: Added embedding from commercial.pt with weight 0.2
# Image 21: Primary function is residential, using residential as the embedding keyword.
# Image 21: Extracted features and scaled by 0.8
# Image 21: Added embedding from residential.pt with weight 0.2
# Image 23: Primary function is hotel, using hotel as the embedding keyword.
# Image 23: Extracted features and scaled by 0.8
# Image 23: Added embedding from hotel.pt with weight 0.2
# Image 25: Primary function is sports and recreation, using sports as the embedding keyword.
# Image 25: Extracted features and scaled by 0.8
# Image 25: Added embedding from sports.pt with weight 0.2
# Image 26: Primary function is residential, using residential as the embedding keyword.
# Image 26: Extracted features and scaled by 0.8
# Image 26: Added embedding from residential.pt with weight 0.2
# Image 31: Primary function is sports and recreation, using sports as the embedding keyword.
# Image 31: Extracted features and scaled by 0.8
# Image 31: Added embedding from sports.pt with weight 0.2
# Image 33: Primary function is commercial, using commercial as the embedding keyword.
# Image 33: Extracted features and scaled by 0.8
# Image 33: Added embedding from commercial.pt with weight 0.2
# Image 38: Primary function is commercial, using commercial as the embedding keyword.
# Image 38: Extracted features and scaled by 0.8
# Image 38: Added embedding from commercial.pt with weight 0.2
# Image 41: Primary function is commercial, using commercial as the embedding keyword.
# Image 41: Extracted features and scaled by 0.8
# Image 41: Added embedding from commercial.pt with weight 0.2
# Image 43: Primary function is education, using education as the embedding keyword.
# Image 43: Extracted features and scaled by 0.8
# Image 43: Added embedding from education.pt with weight 0.2
# Image 48: Primary function is transportation, using transportation as the embedding keyword.
# Image 48: Extracted features and scaled by 0.8
# Image 48: Added embedding from transportation.pt with weight 0.2
# Image 55: Primary function is sports and recreation, using sports as the embedding keyword.
# Processing ./anchor:  21%|██        | 30/143 [00:00<00:01, 56.96it/s]
# Image 55: Extracted features and scaled by 0.8
# Image 55: Added embedding from sports.pt with weight 0.2
# Image 57: Primary function is transportation, using transportation as the embedding keyword.
# Image 57: Extracted features and scaled by 0.8
# Image 57: Added embedding from transportation.pt with weight 0.2
# Image 65: Primary function is education, using education as the embedding keyword.
# Image 65: Extracted features and scaled by 0.8
# Image 65: Added embedding from education.pt with weight 0.2
# Image 70: Primary function is health care, using health as the embedding keyword.
# Image 70: Extracted features and scaled by 0.8
# Image 70: Added embedding from health.pt with weight 0.2
# Image 71: Primary function is hotel, using hotel as the embedding keyword.
# Image 71: Extracted features and scaled by 0.8
# Image 71: Added embedding from hotel.pt with weight 0.2
# Image 72: Primary function is transportation, using transportation as the embedding keyword.
# Image 72: Extracted features and scaled by 0.8
# Image 72: Added embedding from transportation.pt with weight 0.2
# Image 73: Primary function is commercial, using commercial as the embedding keyword.
# Image 73: Extracted features and scaled by 0.8
# Image 73: Added embedding from commercial.pt with weight 0.2
# Image 86: Primary function is health care, using health as the embedding keyword.
# Image 86: Extracted features and scaled by 0.8
# Image 86: Added embedding from health.pt with weight 0.2
# Image 87: Primary function is transportation, using transportation as the embedding keyword.
# Image 87: Extracted features and scaled by 0.8
# Image 87: Added embedding from transportation.pt with weight 0.2
# Image 88: Primary function is residential, using residential as the embedding keyword.
# Image 88: Extracted features and scaled by 0.8
# Image 88: Added embedding from residential.pt with weight 0.2
# Image 95: Primary function is industrial, using industrial as the embedding keyword.
# Image 95: Extracted features and scaled by 0.8
# Image 95: Added embedding from industrial.pt with weight 0.2
# Image 96: Primary function is industrial, using industrial as the embedding keyword.
# Image 96: Extracted features and scaled by 0.8
# Image 96: Added embedding from industrial.pt with weight 0.2
# Image 98: Primary function is commercial, using commercial as the embedding keyword.
# Processing ./anchor:  29%|██▉       | 42/143 [00:00<00:01, 57.35it/s]
# Image 98: Extracted features and scaled by 0.8
# Image 98: Added embedding from commercial.pt with weight 0.2
# Image 99: Primary function is transportation, using transportation as the embedding keyword.
# Image 99: Extracted features and scaled by 0.8
# Image 99: Added embedding from transportation.pt with weight 0.2
# Image 100: Primary function is commercial, using commercial as the embedding keyword.
# Image 100: Extracted features and scaled by 0.8
# Image 100: Added embedding from commercial.pt with weight 0.2
# Image 106: Primary function is commercial, using commercial as the embedding keyword.
# Image 106: Extracted features and scaled by 0.8
# Image 106: Added embedding from commercial.pt with weight 0.2
# Image 107: Primary function is industrial, using industrial as the embedding keyword.
# Image 107: Extracted features and scaled by 0.8
# Image 107: Added embedding from industrial.pt with weight 0.2
# Image 108: Primary function is commercial, using commercial as the embedding keyword.
# Image 108: Extracted features and scaled by 0.8
# Image 108: Added embedding from commercial.pt with weight 0.2
# Image 118: Primary function is residential, using residential as the embedding keyword.
# Image 118: Extracted features and scaled by 0.8
# Image 118: Added embedding from residential.pt with weight 0.2
# Image 119: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Image 119: Extracted features and scaled by 0.8
# Image 119: Added embedding from outdoors.pt with weight 0.2
# Image 121: Primary function is hotel, using hotel as the embedding keyword.
# Image 121: Extracted features and scaled by 0.8
# Image 121: Added embedding from hotel.pt with weight 0.2
# Image 125: Primary function is transportation, using transportation as the embedding keyword.
# Image 125: Extracted features and scaled by 0.8
# Image 125: Added embedding from transportation.pt with weight 0.2
# Image 130: Primary function is sports and recreation, using sports as the embedding keyword.
# Image 130: Extracted features and scaled by 0.8
# Image 130: Added embedding from sports.pt with weight 0.2
# Image 132: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Image 132: Extracted features and scaled by 0.8
# Image 132: Added embedding from outdoors.pt with weight 0.2
# Image 133: Primary function is residential, using residential as the embedding keyword.
# Processing ./anchor:  38%|███▊      | 54/143 [00:00<00:01, 57.07it/s]
# Image 133: Extracted features and scaled by 0.8
# Image 133: Added embedding from residential.pt with weight 0.2
# Image 135: Primary function is residential, using residential as the embedding keyword.
# Image 135: Extracted features and scaled by 0.8
# Image 135: Added embedding from residential.pt with weight 0.2
# Image 144: Primary function is transportation, using transportation as the embedding keyword.
# Image 144: Extracted features and scaled by 0.8
# Image 144: Added embedding from transportation.pt with weight 0.2
# Image 157: Primary function is commercial, using commercial as the embedding keyword.
# Image 157: Extracted features and scaled by 0.8
# Image 157: Added embedding from commercial.pt with weight 0.2
# Image 159: Primary function is residential, using residential as the embedding keyword.
# Image 159: Extracted features and scaled by 0.8
# Image 159: Added embedding from residential.pt with weight 0.2
# Image 167: Primary function is industrial, using industrial as the embedding keyword.
# Image 167: Extracted features and scaled by 0.8
# Image 167: Added embedding from industrial.pt with weight 0.2
# Image 174: Primary function is education, using education as the embedding keyword.
# Image 174: Extracted features and scaled by 0.8
# Image 174: Added embedding from education.pt with weight 0.2
# Image 179: Primary function is hotel, using hotel as the embedding keyword.
# Image 179: Extracted features and scaled by 0.8
# Image 179: Added embedding from hotel.pt with weight 0.2
# Image 182: Primary function is sports and recreation, using sports as the embedding keyword.
# Image 182: Extracted features and scaled by 0.8
# Image 182: Added embedding from sports.pt with weight 0.2
# Image 185: Primary function is sports and recreation, using sports as the embedding keyword.
# Image 185: Extracted features and scaled by 0.8
# Image 185: Added embedding from sports.pt with weight 0.2
# Image 187: Primary function is residential, using residential as the embedding keyword.
# Image 187: Extracted features and scaled by 0.8
# Image 187: Added embedding from residential.pt with weight 0.2
# Image 195: Primary function is commercial, using commercial as the embedding keyword.
# Image 195: Extracted features and scaled by 0.8
# Image 195: Added embedding from commercial.pt with weight 0.2
# Image 196: Primary function is sports and recreation, using sports as the embedding keyword.
# Processing ./anchor:  46%|████▌     | 66/143 [00:01<00:01, 56.85it/s]
# Image 196: Extracted features and scaled by 0.8
# Image 196: Added embedding from sports.pt with weight 0.2
# Image 198: Primary function is civic, governmental and cultural, using civic as the embedding keyword.
# Image 198: Extracted features and scaled by 0.8
# Image 198: Added embedding from civic.pt with weight 0.2
# Image 200: Primary function is health care, using health as the embedding keyword.
# Image 200: Extracted features and scaled by 0.8
# Image 200: Added embedding from health.pt with weight 0.2
# Image 205: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Image 205: Extracted features and scaled by 0.8
# Image 205: Added embedding from outdoors.pt with weight 0.2
# Image 208: Primary function is residential, using residential as the embedding keyword.
# Image 208: Extracted features and scaled by 0.8
# Image 208: Added embedding from residential.pt with weight 0.2
# Image 210: Primary function is residential, using residential as the embedding keyword.
# Image 210: Extracted features and scaled by 0.8
# Image 210: Added embedding from residential.pt with weight 0.2
# Image 223: Primary function is civic, governmental and cultural, using civic as the embedding keyword.
# Image 223: Extracted features and scaled by 0.8
# Image 223: Added embedding from civic.pt with weight 0.2
# Image 228: Primary function is civic, governmental and cultural, using civic as the embedding keyword.
# Image 228: Extracted features and scaled by 0.8
# Image 228: Added embedding from civic.pt with weight 0.2
# Image 236: Primary function is transportation, using transportation as the embedding keyword.
# Image 236: Extracted features and scaled by 0.8
# Image 236: Added embedding from transportation.pt with weight 0.2
# Image 237: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Image 237: Extracted features and scaled by 0.8
# Image 237: Added embedding from outdoors.pt with weight 0.2
# Image 256: Primary function is industrial, using industrial as the embedding keyword.
# Image 256: Extracted features and scaled by 0.8
# Image 256: Added embedding from industrial.pt with weight 0.2
# Image 263: Primary function is transportation, using transportation as the embedding keyword.
# Image 263: Extracted features and scaled by 0.8
# Image 263: Added embedding from transportation.pt with weight 0.2
# Image 285: Primary function is commercial, using commercial as the embedding keyword.
# Processing ./anchor:  55%|█████▍    | 78/143 [00:01<00:01, 57.09it/s]
# Image 285: Extracted features and scaled by 0.8
# Image 285: Added embedding from commercial.pt with weight 0.2
# Image 293: Primary function is commercial, using commercial as the embedding keyword.
# Image 293: Extracted features and scaled by 0.8
# Image 293: Added embedding from commercial.pt with weight 0.2
# Image 295: Primary function is residential, using residential as the embedding keyword.
# Image 295: Extracted features and scaled by 0.8
# Image 295: Added embedding from residential.pt with weight 0.2
# Image 301: Primary function is commercial, using commercial as the embedding keyword.
# Image 301: Extracted features and scaled by 0.8
# Image 301: Added embedding from commercial.pt with weight 0.2
# Image 304: Primary function is transportation, using transportation as the embedding keyword.
# Image 304: Extracted features and scaled by 0.8
# Image 304: Added embedding from transportation.pt with weight 0.2
# Image 316: Primary function is education, using education as the embedding keyword.
# Image 316: Extracted features and scaled by 0.8
# Image 316: Added embedding from education.pt with weight 0.2
# Image 318: Primary function is transportation, using transportation as the embedding keyword.
# Image 318: Extracted features and scaled by 0.8
# Image 318: Added embedding from transportation.pt with weight 0.2
# Image 334: Primary function is residential, using residential as the embedding keyword.
# Image 334: Extracted features and scaled by 0.8
# Image 334: Added embedding from residential.pt with weight 0.2
# Image 339: Primary function is industrial, using industrial as the embedding keyword.
# Image 339: Extracted features and scaled by 0.8
# Image 339: Added embedding from industrial.pt with weight 0.2
# Image 365: Primary function is hotel, using hotel as the embedding keyword.
# Image 365: Extracted features and scaled by 0.8
# Image 365: Added embedding from hotel.pt with weight 0.2
# Image 377: Primary function is commercial, using commercial as the embedding keyword.
# Image 377: Extracted features and scaled by 0.8
# Image 377: Added embedding from commercial.pt with weight 0.2
# Image 378: Primary function is commercial, using commercial as the embedding keyword.
# Image 378: Extracted features and scaled by 0.8
# Image 378: Added embedding from commercial.pt with weight 0.2
# Image 392: Primary function is commercial, using commercial as the embedding keyword.
# Processing ./anchor:  63%|██████▎   | 90/143 [00:01<00:00, 56.43it/s]
# Image 392: Extracted features and scaled by 0.8
# Image 392: Added embedding from commercial.pt with weight 0.2
# Image 411: Primary function is commercial, using commercial as the embedding keyword.
# Image 411: Extracted features and scaled by 0.8
# Image 411: Added embedding from commercial.pt with weight 0.2
# Image 422: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Image 422: Extracted features and scaled by 0.8
# Image 422: Added embedding from outdoors.pt with weight 0.2
# Image 454: Primary function is health care, using health as the embedding keyword.
# Image 454: Extracted features and scaled by 0.8
# Image 454: Added embedding from health.pt with weight 0.2
# Image 466: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Image 466: Extracted features and scaled by 0.8
# Image 466: Added embedding from outdoors.pt with weight 0.2
# Image 468: Primary function is education, using education as the embedding keyword.
# Image 468: Extracted features and scaled by 0.8
# Image 468: Added embedding from education.pt with weight 0.2
# Image 474: Primary function is residential, using residential as the embedding keyword.
# Image 474: Extracted features and scaled by 0.8
# Image 474: Added embedding from residential.pt with weight 0.2
# Image 483: Primary function is health care, using health as the embedding keyword.
# Image 483: Extracted features and scaled by 0.8
# Image 483: Added embedding from health.pt with weight 0.2
# Image 506: Primary function is residential, using residential as the embedding keyword.
# Image 506: Extracted features and scaled by 0.8
# Image 506: Added embedding from residential.pt with weight 0.2
# Image 517: Primary function is transportation, using transportation as the embedding keyword.
# Image 517: Extracted features and scaled by 0.8
# Image 517: Added embedding from transportation.pt with weight 0.2
# Image 543: Primary function is education, using education as the embedding keyword.
# Image 543: Extracted features and scaled by 0.8
# Image 543: Added embedding from education.pt with weight 0.2
# Image 556: Primary function is civic, governmental and cultural, using civic as the embedding keyword.
# Image 556: Extracted features and scaled by 0.8
# Image 556: Added embedding from civic.pt with weight 0.2
# Image 571: Primary function is sports and recreation, using sports as the embedding keyword.
# Processing ./anchor:  71%|███████▏  | 102/143 [00:01<00:00, 57.15it/s]
# Image 571: Extracted features and scaled by 0.8
# Image 571: Added embedding from sports.pt with weight 0.2
# Image 589: Primary function is commercial, using commercial as the embedding keyword.
# Image 589: Extracted features and scaled by 0.8
# Image 589: Added embedding from commercial.pt with weight 0.2
# Image 590: Primary function is industrial, using industrial as the embedding keyword.
# Image 590: Extracted features and scaled by 0.8
# Image 590: Added embedding from industrial.pt with weight 0.2
# Image 593: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Image 593: Extracted features and scaled by 0.8
# Image 593: Added embedding from outdoors.pt with weight 0.2
# Image 616: Primary function is commercial, using commercial as the embedding keyword.
# Image 616: Extracted features and scaled by 0.8
# Image 616: Added embedding from commercial.pt with weight 0.2
# Image 621: Primary function is education, using education as the embedding keyword.
# Image 621: Extracted features and scaled by 0.8
# Image 621: Added embedding from education.pt with weight 0.2
# Image 637: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Image 637: Extracted features and scaled by 0.8
# Image 637: Added embedding from outdoors.pt with weight 0.2
# Image 652: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Image 652: Extracted features and scaled by 0.8
# Image 652: Added embedding from outdoors.pt with weight 0.2
# Image 702: Primary function is residential, using residential as the embedding keyword.
# Image 702: Extracted features and scaled by 0.8
# Image 702: Added embedding from residential.pt with weight 0.2
# Image 709: Primary function is education, using education as the embedding keyword.
# Image 709: Extracted features and scaled by 0.8
# Image 709: Added embedding from education.pt with weight 0.2
# Image 717: Primary function is sports and recreation, using sports as the embedding keyword.
# Image 717: Extracted features and scaled by 0.8
# Image 717: Added embedding from sports.pt with weight 0.2
# Image 719: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Image 719: Extracted features and scaled by 0.8
# Image 719: Added embedding from outdoors.pt with weight 0.2
# Image 722: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Processing ./anchor:  80%|███████▉  | 114/143 [00:02<00:00, 56.80it/s]
# Image 722: Extracted features and scaled by 0.8
# Image 722: Added embedding from outdoors.pt with weight 0.2
# Image 751: Primary function is commercial, using commercial as the embedding keyword.
# Image 751: Extracted features and scaled by 0.8
# Image 751: Added embedding from commercial.pt with weight 0.2
# Image 752: Primary function is residential, using residential as the embedding keyword.
# Image 752: Extracted features and scaled by 0.8
# Image 752: Added embedding from residential.pt with weight 0.2
# Image 769: Primary function is industrial, using industrial as the embedding keyword.
# Image 769: Extracted features and scaled by 0.8
# Image 769: Added embedding from industrial.pt with weight 0.2
# Image 781: Primary function is industrial, using industrial as the embedding keyword.
# Image 781: Extracted features and scaled by 0.8
# Image 781: Added embedding from industrial.pt with weight 0.2
# Image 802: Primary function is education, using education as the embedding keyword.
# Image 802: Extracted features and scaled by 0.8
# Image 802: Added embedding from education.pt with weight 0.2
# Image 825: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Image 825: Extracted features and scaled by 0.8
# Image 825: Added embedding from outdoors.pt with weight 0.2
# Image 858: Primary function is civic, governmental and cultural, using civic as the embedding keyword.
# Image 858: Extracted features and scaled by 0.8
# Image 858: Added embedding from civic.pt with weight 0.2
# Image 865: Primary function is education, using education as the embedding keyword.
# Image 865: Extracted features and scaled by 0.8
# Image 865: Added embedding from education.pt with weight 0.2
# Image 873: Primary function is hotel, using hotel as the embedding keyword.
# Image 873: Extracted features and scaled by 0.8
# Image 873: Added embedding from hotel.pt with weight 0.2
# Image 890: Primary function is health care, using health as the embedding keyword.
# Image 890: Extracted features and scaled by 0.8
# Image 890: Added embedding from health.pt with weight 0.2
# Image 915: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Image 915: Extracted features and scaled by 0.8
# Image 915: Added embedding from outdoors.pt with weight 0.2
# Image 946: Primary function is commercial, using commercial as the embedding keyword.
# Processing ./anchor:  88%|████████▊ | 126/143 [00:02<00:00, 56.64it/s]
# Image 946: Extracted features and scaled by 0.8
# Image 946: Added embedding from commercial.pt with weight 0.2
# Image 983: Primary function is commercial, using commercial as the embedding keyword.
# Image 983: Extracted features and scaled by 0.8
# Image 983: Added embedding from commercial.pt with weight 0.2
# Image 1021: Primary function is transportation, using transportation as the embedding keyword.
# Image 1021: Extracted features and scaled by 0.8
# Image 1021: Added embedding from transportation.pt with weight 0.2
# Image 1062: Primary function is commercial, using commercial as the embedding keyword.
# Image 1062: Extracted features and scaled by 0.8
# Image 1062: Added embedding from commercial.pt with weight 0.2
# Image 1073: Primary function is residential, using residential as the embedding keyword.
# Image 1073: Extracted features and scaled by 0.8
# Image 1073: Added embedding from residential.pt with weight 0.2
# Image 1087: Primary function is education, using education as the embedding keyword.
# Image 1087: Extracted features and scaled by 0.8
# Image 1087: Added embedding from education.pt with weight 0.2
# Image 1110: Primary function is education, using education as the embedding keyword.
# Image 1110: Extracted features and scaled by 0.8
# Image 1110: Added embedding from education.pt with weight 0.2
# Image 1111: Primary function is education, using education as the embedding keyword.
# Image 1111: Extracted features and scaled by 0.8
# Image 1111: Added embedding from education.pt with weight 0.2
# Image 1166: Primary function is residential, using residential as the embedding keyword.
# Image 1166: Extracted features and scaled by 0.8
# Image 1166: Added embedding from residential.pt with weight 0.2
# Image 1175: Primary function is commercial, using commercial as the embedding keyword.
# Image 1175: Extracted features and scaled by 0.8
# Image 1175: Added embedding from commercial.pt with weight 0.2
# Image 1180: Primary function is residential, using residential as the embedding keyword.
# Image 1180: Extracted features and scaled by 0.8
# Image 1180: Added embedding from residential.pt with weight 0.2
# Image 1219: Primary function is civic, governmental and cultural, using civic as the embedding keyword.
# Image 1219: Extracted features and scaled by 0.8
# Image 1219: Added embedding from civic.pt with weight 0.2
# Image 1232: Primary function is transportation, using transportation as the embedding keyword.
# Processing ./anchor:  97%|█████████▋| 138/143 [00:02<00:00, 56.25it/s]
# Image 1232: Extracted features and scaled by 0.8
# Image 1232: Added embedding from transportation.pt with weight 0.2
# Image 1233: Primary function is residential, using residential as the embedding keyword.
# Image 1233: Extracted features and scaled by 0.8
# Image 1233: Added embedding from residential.pt with weight 0.2
# Image 1246: Primary function is civic, governmental and cultural, using civic as the embedding keyword.
# Image 1246: Extracted features and scaled by 0.8
# Image 1246: Added embedding from civic.pt with weight 0.2
# Image 1265: Primary function is outdoors and natural, using outdoors as the embedding keyword.
# Image 1265: Extracted features and scaled by 0.8
# Image 1265: Added embedding from outdoors.pt with weight 0.2
# Image 1286: Primary function is civic, governmental and cultural, using civic as the embedding keyword.
# Image 1286: Extracted features and scaled by 0.8
# Image 1286: Added embedding from civic.pt with weight 0.2
# Image 1291: Primary function is civic, governmental and cultural, using civic as the embedding keyword.
# Image 1291: Extracted features and scaled by 0.8
# Image 1291: Added embedding from civic.pt with weight 0.2
# Image 1303: Primary function is civic, governmental and cultural, using civic as the embedding keyword.
# Image 1303: Extracted features and scaled by 0.8
# Image 1303: Added embedding from civic.pt with weight 0.2
# Image 1308: Primary function is health care, using health as the embedding keyword.
# Image 1308: Extracted features and scaled by 0.8
# Image 1308: Added embedding from health.pt with weight 0.2
# Image 1320: Primary function is health care, using health as the embedding keyword.
# Image 1320: Extracted features and scaled by 0.8
# Image 1320: Added embedding from health.pt with weight 0.2
# Image 1356: Primary function is education, using education as the embedding keyword.
# Image 1356: Extracted features and scaled by 0.8
# Image 1356: Added embedding from education.pt with weight 0.2
# Image 1428: Primary function is education, using education as the embedding keyword.
# Image 1428: Extracted features and scaled by 0.8
# Image 1428: Added embedding from education.pt with weight 0.2
# Image 1461: Primary function is education, using education as the embedding keyword.
# Processing ./anchor: 100%|██████████| 143/143 [00:02<00:00, 56.61it/s]
# Image 1461: Extracted features and scaled by 0.8
# Image 1461: Added embedding from education.pt with weight 0.2
# Features saved to ./imgs_anchor
